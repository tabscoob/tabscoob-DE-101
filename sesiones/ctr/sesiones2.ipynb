# %%
import pandas as pd

# %% [markdown]
# ## Configurar imprimir todo el contenido de la columna

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_ratings= pd.read_csv('../../resources/kaggle.com_datasets_rounakbanik_the-movies-dataset/ratings_small.csv')
df_keywords= pd.read_csv('../../resources/kaggle.com_datasets_rounakbanik_the-movies-dataset/keywords.csv')
df_credits= pd.read_csv('../../resources/kaggle.com_datasets_rounakbanik_the-movies-dataset/credits.csv')
df_links= pd.read_csv('../../resources/kaggle.com_datasets_rounakbanik_the-movies-dataset/links.csv')
df_movies_metadata= pd.read_csv('../../resources/kaggle.com_datasets_rounakbanik_the-movies-dataset/movies_metadata.csv')
# Out:
# C:\Users\lina9\AppData\Local\Temp\ipykernel_23684\309796610.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies_metadata= pd.read_csv('../../resources/kaggle.com_datasets_rounakbanik_the-movies-dataset/movies_metadata.csv')

# %% [markdown]
# ## Imprimir los primeros 3 registros de cada dataframe

# %%
# df_ratings
df_ratings.iloc[:3]
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182

# %%
df_keywords.iloc[:3]
# Out:
#       id  \
# 0    862
# 1   8844
# 2  15602
#
#                                                                                                                                                                                                                                                                                                                      keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]
# ...

# %%
df_credits.iloc[:3]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df_links.iloc[:3]
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0

# %% [markdown]
# ## Imprimir el esquema de cada dataframe

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
df_keywords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46419 entries, 0 to 46418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46419 non-null  int64
#  1   keywords  46419 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 725.4+ KB

# %%
df_movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
#contar el total de registros por columna
df_movies_metadata.count()
# Out:
# adult                    45466
# belongs_to_collection     4494
# budget                   45466
# genres                   45466
# homepage                  7782
# id                       45466
# imdb_id                  45449
# original_language        45455
# original_title           45466
# overview                 44512
# popularity               45461
# poster_path              45080
# production_companies     45463
# production_countries     45463
# release_date             45379
# revenue                  45460
# runtime                  45203
# spoken_languages         45460
# status                   45379
# tagline                  20412
# title                    45460
# video                    45460
# vote_average             45460
# vote_count               45460
# dtype: int64

# %%
# contar el total de regristros en el dataset
df_movies_metadata.shape[0]
# Out:
# 45466

# %% [markdown]
# ## Filtrar datos en el dataset

# %% [markdown]
# Filtrar dataset con todas las películas que salieron en el año 2000

# %%
peliculas_del_2000_df=df_movies_metadata[(df_movies_metadata["release_date"]>='2000-01-01') & (df_movies_metadata["release_date"]<='2000-12-31')].filter(items=['id', 'title', 'release_date', 'spoken_languages'])

# %%
df_movies_metadata[df_movies_metadata["release_date"]=='1995-12-15'].filter(items=['id', 'title', 'release_date'])
# Out:
#           id                     title release_date
# 1       8844                   Jumanji   1995-12-15
# 5        949                      Heat   1995-12-15
# 6      11860                   Sabrina   1995-12-15
# 25     16420                   Othello   1995-12-15
# 39     34615  Cry, the Beloved Country   1995-12-15
# 14518  55261           Hidden Assassin   1995-12-15
# 25913  56804           Viaggi di nozze   1995-12-15

# %%
peliculas_del_2000_df[peliculas_del_2000_df["spoken_languages"].str.contains("Español")]
# Out:
#            id                                                 title  \
# 2654    19457                                             The Yards
# 3183     2069                                  The Whole Nine Yards
# 3413     1359                                       American Psycho
# 3414     4967                                     Keeping the Faith
# 3432    14736                                     Love & Basketball
# 3440    40562                                             Committed
# 3445    19600                                            Bossa Nova
# 3502     8584                                         Shanghai Noon
# 3622      479                                                 Shaft
# 3760    19150                                              The Crew
# 3769    10480                                           Nurse Betty
# 3775    51179                                                Circus
# 3782    10562                                       Under Suspicion
# ...
